# %%
import numpy as np
import random

np.random.seed(42)
random.seed(42)

# %%
# !python -m train.train_cGAN --epochs 50

# %%
# !python -m eval.eval_cGAN --save-path "./experiments/c_gan_best.pth" --clf-path "./experiments/classfier_best.pth" --num-samples 100000 --batch 256
